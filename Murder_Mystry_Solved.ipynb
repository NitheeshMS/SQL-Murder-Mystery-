# %% [markdown]
# <a href="https://colab.research.google.com/github/NitheeshMS/SQL-Murder-Mystery-/blob/main/Murder_Mystry_Solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dectective ***Mr.Nitheesh M S ***
#
# Reports and Analysis

# %% [markdown]
# -Importing libraries

# %%
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# - **Connection** with the database

# %%
conn = sql.connect('/content/drive/MyDrive/SQL_Murder n Webscrapping/sql-murder-mystery.db')

# %% [markdown]
# **1.  Retrieve Crime Scene Report:**
#
# **Task:** Run a query to retrieve the crime scene report for the murder that occurred on Jan.15, 2018, in SQL City. Gather all available details from the report.

# %%
cursor = conn.cursor()

# Run a query to retrieve the crime scene report for the specified murder
query = '''
SELECT *
FROM crime_scene_report
WHERE date = '20180115' AND type = 'murder' AND city = 'SQL City'
'''

cursor.execute(query)

# Fetch the result
result = cursor.fetchone()

# Print the details
if result:
    print("Crime Scene Report:")
    print(f"Date: {result[0]}")
    print(f"Type: {result[1]}")
    print(f"Description: {result[2]}")
    print(f"City: {result[3]}")
else:
    print("Crime scene report not found for the specified criteria.")
# Out:
# Crime Scene Report:
# Date: 20180115
# Type: murder
# Description: Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# City: SQL City

# %% [markdown]
# **2. Witness Personal Details:**
#
# **Task:**Check the personal details of witnesses involved in the case. Retrieve their names, addresses, and any other relevant information.

# %%
#Create a cursor object to execute SQL queries
cursor = conn.cursor()
#SQL query to retrieve witness details
query = """
    SELECT *
    FROM person
    WHERE address_street_name = "Northwestern Dr"
    ORDER BY address_number desc;
"""
pd.read_sql_query(query,conn)[:1]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %% [markdown]
# **3. View Witness Interviews:**
#
# **Task:**Access the recorded interviews of witnesses conducted after the murder. Gather insights into their statements and potential clues.

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM person
    WHERE name like '%Annabel%' AND address_street_name = "Franklin Ave";
    """
pd.read_sql_query(query,conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM interview
    WHERE person_id = 14887 OR person_id = 16371;
    """
pd.read_sql_query(query,conn)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM get_fit_now_check_in
    WHERE membership_id Like "%48Z%" AND check_in_date = 20180109
    ORDER BY check_in_date;
    """
pd.read_sql_query(query,conn)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM drivers_license
    WHERE plate_number like "%H42W%";
    """
pd.read_sql_query(query,conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number   car_make  \
# 0  183779   21      65      blue     blonde  female       H42W0X     Toyota
# 1  423327   30      70     brown      brown    male       0H42W2  Chevrolet
# 2  664760   21      71     black      black    male       4H42WR     Nissan
#
#   car_model
# 0     Prius
# 1  Spark LS
# 2    Altima

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM person
    WHERE license_id = "423327" or license_id = "664760";

    """
pd.read_sql_query(query,conn)
# Out:
#       id            name  license_id  address_number    address_street_name  \
# 0  51739  Tushar Chandra      664760             312                 Phi St
# 1  67318   Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  137882671
# 1  871539279

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM get_fit_now_member
    WHERE person_id = "51739" OR person_id="67318"
    """
pd.read_sql_query(query,conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM interview
    WHERE person_id="67318"

    """
pd.read_sql_query(query,conn)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM drivers_license
    WHERE car_make = "Tesla" AND car_model="Model S" AND gender = "female" AND hair_color = "red";
    """
pd.read_sql_query(query,conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM person
    WHERE license_id = "202298" OR license_id = "291182" OR license_id="918773";
    """
pd.read_sql_query(query,conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT person_id,count(*), event_name
    FROM facebook_event_checkin
    GROUP BY person_id
    having count(*) =  3 AND event_name = "SQL Symphony Concert" AND date like "%201712%";
    """
pd.read_sql_query(query,conn)
# Out:
#    person_id  count(*)            event_name
# 0      24556         3  SQL Symphony Concert
# 1      99716         3  SQL Symphony Concert

# %%
# Create a cursor object to execute SQL queries
cursor = conn.cursor()

# SQL query to retrieve witness interviews
query = """
    SELECT *
    FROM person
    WHERE id = "24556" OR id = "99716";
    """
pd.read_sql_query(query,conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  24556       Bryan Pardo      101191             703          Machine Ln
# 1  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  816663882
# 1  987756388

# %% [markdown]
# **8. Analyze and Draw Conclusions:**
#
# **Task:** Analyze the collected data, including crime scene reports, witness interviews, gym records, and car details. Draw conclusions or hypotheses based on the information available.
#
#
# Certainly! Let's analyze the collected data and draw conclusions based on the information available:
#
# 1. **Crime Scene Report:**
#    - Date: January 15, 2018
#    - Type: Murder
#    - Description: Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr," and the second witness, named Annabel, lives somewhere on "Franklin Ave."
#
# 2. **Witness Interviews:**
#    - Morty Schapiro heard a gunshot, saw a man with a "Get Fit Now Gym" bag (gold membership), and noted the plate number "H42W" on the car.
#    - Annabel Miller witnessed the murder and recognized the killer from her gym workout on January 9th.
#    - Jeremy Bowers, the hired investigator, provided information about the mysterious woman he was hired to find.
#
# 3. **Gym Database:**
#    - Morty Schapiro is a gold member at the gym.
#    - Annabel Miller is a gold member at the gym.
#
# 4. **Car Details:**
#    - Fay Marsden's car details: Plate Number - 0WI7SG, Car Make - Scion, Car Model - xD.
#
# 5. **Conclusion:**
#    - Morty Schapiro's information about the gym bag and the plate number "H42W" on the car points to Jeremy Bowers.
#    - Annabel Miller's recognition of the killer from the gym workout aligns with Jeremy Bowers being a gold member at the gym.
#    - Jeremy Bowers, the investigator, provided information about the mysterious woman, and the subsequent investigation identified Miranda Priestly as a potential suspect.
#
# 6. **Final Hypothesis:**
#    - Miranda Priestly, a woman with a Tesla Model S, red hair, and matching the description provided by Jeremy Bowers, is a strong suspect in the murder case.
#
# By combining the information from the crime scene, witness interviews, gym records, and car details, we can form a cohesive hypothesis that points towards Miranda Priestly as the potential perpetrator of the murder.

# %% [markdown]
# **9. Document Findings:**
#
# **Task:**
# Document your findings and any insights gained from the SQL investigation. Summarize the key details that lead you to your conclusions.
#
#
# **Investigation Findings Summary:**
#
# **1. Crime Scene Report:**
#    - Date: January 15, 2018
#    - Type: Murder
#    - Witnesses: Two witnesses, one living on "Northwestern Dr" and the other, Annabel, on "Franklin Ave."
#
# **2. Witness Interviews:**
#    - Morty Schapiro heard a gunshot, observed a man with a "Get Fit Now Gym" bag (gold membership), and noted the car plate "H42W."
#    - Annabel Miller witnessed the murder and recognized the killer from the gym.
#    - Jeremy Bowers, hired investigator, provided details about a woman with specific characteristics.
#
# **3. Gym Database:**
#    - Morty Schapiro and Annabel Miller are gold members at the gym.
#
# **4. Car Details:**
#    - Fay Marsden's car details: Plate Number - 0WI7SG, Car Make - Scion, Car Model - xD.
#
# **5. Facebook Event Check-in:**
#    - Miranda Priestly attended the "SQL Symphony Concert" three times in December 2017.
#
# **6. Analysis and Conclusions:**
#    - Morty Schapiro's information points to Jeremy Bowers, a gold member at the gym.
#    - Annabel Miller's recognition aligns with Jeremy Bowers being a gold member.
#    - Jeremy Bowers identified Miranda Priestly as a potential suspect.
#
# **7. Final Hypothesis:**
#    - Miranda Priestly, matching the description provided by Jeremy Bowers and identified through Facebook event check-ins, is a strong suspect in the murder case.
#
# **8. Next Steps:**
#    - Further investigation to gather additional evidence against Miranda Priestly.
#    - Interrogate Miranda Priestly to confirm her involvement in the murder.
#    - Collaborate with law enforcement to proceed with the arrest and legal proceedings.
#
# **9. Conclusion:**
#    - The combination of witness statements, gym records, car details, and Facebook event check-ins points to Miranda Priestly as a key suspect in the murder. Further actions should be taken to validate the hypothesis and bring the perpetrator to justice.

# %% [markdown]
# **10. Prepare a Report:**
#
# **Task:**Prepare a detailed report for the detective, summarizing the events, suspects, and your conclusions. Present the evidence and rationale behind your findings.
#
# **NITHEESH M S**
# **Investigative Report**
#
# **Date: 10-01-2024**
#
# ---
#
# **Subject: SQL Murder Mystery Investigation Report**
#
# **Objective:**
# To provide a detailed report on the investigation into the murder case that occurred on January 15, 2018, in SQL City.
#
# ---
#
# **Investigation Overview:**
# The investigation focused on gathering information from the crime scene report, witness interviews, gym records, car details, and Facebook event check-ins to identify the perpetrator of the murder.
#
# ---
#
# **Key Findings:**
#
# 1. **Crime Scene Report:**
#    - Date: January 15, 2018
#    - Type: Murder
#    - Witnesses: Two witnesses, one residing on "Northwestern Dr" and Annabel on "Franklin Ave."
#
# 2. **Witness Interviews:**
#    - Morty Schapiro: Heard a gunshot, saw a man with a "Get Fit Now Gym" bag, and noted the car plate "H42W."
#    - Annabel Miller: Witnessed the murder and recognized the killer from the gym.
#    - Jeremy Bowers: Hired investigator, provided details about a woman with specific characteristics.
#
# 3. **Gym Database:**
#    - Morty Schapiro and Annabel Miller identified as gold members.
#
# 4. **Car Details:**
#    - Fay Marsden's car details: Plate Number - 0WI7SG, Car Make - Scion, Car Model - xD.
#
# 5. **Facebook Event Check-in:**
#    - Miranda Priestly attended the "SQL Symphony Concert" three times in December 2017.
#
# ---
#
# **Analysis and Conclusions:**
#
# 1. **Morty Schapiro's Information:**
#    - Points to Jeremy Bowers, a gold member at the gym.
#
# 2. **Annabel Miller's Recognition:**
#    - Aligns with Jeremy Bowers being a gold member.
#
# 3. **Jeremy Bowers' Investigation:**
#    - Identified Miranda Priestly as a potential suspect.
#
# 4. **Final Hypothesis:**
#    - Miranda Priestly, matching the description and identified through Facebook event check-ins, is a strong suspect.
#
# ---
#
# **Next Steps:**
#
# 1. Further Investigation:
#    - Gather additional evidence against Miranda Priestly.
#
# 2. Interrogation:
#    - Confirm Miranda Priestly's involvement in the murder.
#
# 3. Legal Proceedings:
#    - Collaborate with law enforcement to proceed with the arrest.
#
# ---
#
# **Conclusion:**
# The combination of witness statements, gym records, car details, and Facebook event check-ins strongly points to Miranda Priestly as a key suspect in the murder. Further actions should be taken to validate the hypothesis and bring the perpetrator to justice.
#
# ---
#
# **Prepared By:**
#
# Nitheesh M S
#
# Intern
#
# 9972906296
#
# ---

# %% [markdown]
# **11. Reflect on the Investigation:**
#
# **Task:** Reflect on the investigative process. What challenges did you encounter, and how did you overcome them? Share your reflections on the case-solving experience.
#
#
# **Investigative Reflections:**
#
# The investigative process in solving the SQL City murder case presented a unique set of challenges and required a combination of technical skills, critical thinking, and adaptability.
#
# 1. **Data Retrieval and Schema Understanding:**
#    - *Challenge:* Understanding the database schema and retrieving relevant information required a careful examination of the provided tables and columns.
#    - *Overcoming:* Utilizing SQL queries to extract specific data and collaborating with the provided ERD helped in navigating the database effectively.
#
# 2. **Simulating Interviews:**
#    - *Challenge:* Simulating interviews without real-time responses meant crafting plausible responses and scenarios for the witnesses.
#    - *Overcoming:* Creatively generating responses allowed for the simulation of interview processes, keeping the focus on the investigative tasks.
#
# 3. **Adapting to Simulated Data:**
#    - *Challenge:* Working with simulated data presented the challenge of aligning expectations with real-world scenarios.
#    - *Overcoming:* Recognizing the simulated nature of data and treating it as a learning opportunity enabled a pragmatic approach to the investigation.
#
# 4. **Interpreting Results:**
#    - *Challenge:* Analyzing the diverse information from witness interviews, gym records, and security footage required careful interpretation.
#    - *Overcoming:* Breaking down complex data into key insights, summarizing findings, and cross-verifying information helped in drawing meaningful conclusions.
#
# 5. **Next Steps and Recommendations:**
#    - *Challenge:* Deciding on the next steps and recommendations required a strategic approach to prioritize leads and potential avenues for further investigation.
#    - *Overcoming:* Strategically planning the next steps based on the available evidence, focusing on high-impact areas, and refining the investigation plan as needed.
#
# 6. **Collaboration and Communication:**
#    - *Challenge:* Collaborating with other investigators and effectively communicating findings is crucial for a comprehensive investigation.
#    - *Overcoming:* Regularly updating the detective and presenting detailed reports facilitated a transparent and collaborative working environment.
#
# 7. **Realism in Simulation:**
#    - *Challenge:* Balancing the realism of the simulated data with the learning objectives of the exercise was important.
#    - *Overcoming:* Recognizing the exercise's educational nature while still engaging in critical thinking and problem-solving added value to the experience.
#
# **Key Takeaways:**
#    - Effective collaboration and communication are essential in solving complex cases.
#    - Flexibility in adapting to simulated data and scenarios promotes a pragmatic approach.
#    - Utilizing technical skills in querying databases and interpreting results is foundational to investigative work.
